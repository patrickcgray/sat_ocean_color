# %% [markdown]
# ## Inspecting Long term chla and SST around the Gulf Stream
#
# Data downloaded from Google Earth Engine based on MODIS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('chla_sst_overview.csv')

# %%
df.head()
# Out:
#   system:time_start  chlor_a_labrador  chlor_a_oligo  chlor_a_hatteras  \
# 0          1-Jan-16               NaN            NaN               NaN
# 1          2-Jan-16             0.963            NaN             0.602
# 2          3-Jan-16               NaN            NaN               NaN
# 3          4-Jan-16               NaN            NaN               NaN
# 4          5-Jan-16               NaN            NaN               NaN
#
#    sst_labrador  sst_oligo  sst_hatteras
# 0           NaN        NaN           NaN
# 1        16.336        NaN        26.542
# 2           NaN        NaN           NaN
# 3           NaN        NaN           NaN
# 4           NaN        NaN           NaN

# %%
plt.rcParams.update({'font.size': 14})

fig, ax = plt.subplots()
ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

df.plot.scatter(ax=ax, x='system:time_start',
                      y='chlor_a_labrador', c='green', alpha=0.5)
df.plot.scatter(ax=ax2, x='system:time_start',
                      y='sst_labrador', c='red', alpha=0.5)

ax.set_title('Labrador Current')
ax.set_ylim(0,3)
ax2.set_ylim(8,32)

ax2.set_ylabel('Sea Surface Temp (C)')
ax.set_ylabel('Chlorophyll-a (mg/m^3)')
ax.tick_params('x', labelrotation=75, length=10)
frequency = 60
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, frequency))
ax.set_xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
fig, ax = plt.subplots()
ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

df.plot.scatter(ax=ax, x='sst_labrador',
                      y='chlor_a_labrador', c='black', alpha=0.5)

#ax.set_title('Labrador Current')
ax.set_ylim(.2,5)
ax.set_yscale('log')

# %%
fig, ax = plt.subplots()
ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

df.plot.scatter(ax=ax, x='system:time_start',
                      y='chlor_a_oligo', c='green', alpha=0.35)
#ax.plot(df['system:time_start'], df_avg['chlor_a_oligo'], c='darkgreen')

df.plot.scatter(ax=ax2, x='system:time_start',
                      y='sst_oligo', c='red', alpha=0.35)
#ax2.plot(df['system:time_start'], df_avg['sst_oligo'], c='darkred')

ax.set_title("Eastern Gulf Stream")

ax.set_ylim(0,3)
ax2.set_ylim(8,32)

ax2.set_ylabel('Sea Surface Temp (C)')
ax.set_ylabel('Chlorophyll-a (mg/m^3)')
ax.tick_params('x', labelrotation=75, length=10)
frequency = 60
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, frequency))
ax.set_xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
fig, ax = plt.subplots()
ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

df.plot.scatter(ax=ax, x='sst_oligo',
                      y='chlor_a_oligo', c='black', alpha=0.5)

#ax.set_title('Labrador Current')
#ax.set_ylim(0,3)
ax.set_yscale('log')

# %% [markdown]
# Surface plot of lat, llon, slope of chl-sst line, and STD or mean chl concentration

# %%
fig, ax = plt.subplots()
ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

df.plot.scatter(ax=ax, x='system:time_start',
                      y='chlor_a_hatteras', c='green', alpha=0.35)
#ax.plot(df['system:time_start'], df_avg['chlor_a_hatteras'], c='darkgreen')

df.plot.scatter(ax=ax2, x='system:time_start',
                      y='sst_hatteras', c='red', alpha=0.35)
#ax2.plot(df['system:time_start'], df_avg['sst_hatteras'], c='darkred')

ax.set_title('Gulf Stream North Wall')

ax.set_ylim(0,3)
ax2.set_ylim(8,32)

ax2.set_ylabel('Sea Surface Temp (C)')
ax.set_ylabel('Chlorophyll-a (mg/m^3)')
ax.tick_params('x', labelrotation=75, length=10)
frequency = 60
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, frequency))
ax.set_xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
fig, ax = plt.subplots()
ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

df.plot.scatter(ax=ax, x='sst_hatteras',
                      y='chlor_a_hatteras', c='black', alpha=0.5)

#ax.set_title('Labrador Current')
#ax.set_ylim(0,3)
ax.set_yscale('log')

# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False, vmin=8, vmax=33)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
